# %%
import nibabel as nib
import skimage.io as io
import numpy as np
import matplotlib.pyplot as plt
img=nib.load('SMIR.Brain.XX.O.CT_4DPWI.345666.nii')
img_arr=img.get_fdata()
img_arr=np.squeeze(img_arr)
print('img.arr',img_arr.shape)
gw=io.imshow(img_arr[:,:,1,3])
plt.show(gw)
# Out:
# img.arr (256, 256, 4, 44)

# %%
ls
# Out:
#  Volume in drive C is Local Disk
#  Volume Serial Number is 9841-A8CE
#
#  Directory of C:\Users\xw345\PycharmProjects\ISLES2018\data_nini
#
# 10/20/2018  11:39 AM    <DIR>          .
# 10/20/2018  11:39 AM    <DIR>          ..
# 10/20/2018  11:01 AM    <DIR>          .ipynb_checkpoints
# 10/20/2018  10:42 AM               539 counting the nii files.py
# 10/20/2018  10:42 AM               535 counting_nii_files.py
# 10/20/2018  10:42 AM            92,697 Json and nii reading.ipynb
# 10/20/2018  10:42 AM           925,856 nifti1diagrams.pdf
# 07/03/2018  11:33 AM        46,137,696 SMIR.Brain.XX.O.CT_4DPWI.345666.nii
# 07/03/2018  11:34 AM           524,640 SMIR.Brain.XX.O.CT_CBF.345668.nii
# 07/03/2018  11:34 AM           524,640 SMIR.Brain.XX.O.CT_CBV.345669.nii
# 07/03/2018  11:35 AM         2,097,504 SMIR.Brain.XX.O.CT_MTT.345670.nii
# 07/03/2018  11:35 AM         2,097,504 SMIR.Brain.XX.O.CT_Tmax.345672.nii
# 10/20/2018  11:39 AM            19,304 TEST_NII.ipynb
#               10 File(s)     52,420,915 bytes
#                3 Dir(s)  67,499,298,816 bytes free

# %%
import nibabel as nib
import skimage.io as io
import numpy as np
from skimage.transform import rotate
img=nib.load('SMIR.Brain.XX.O.CT_CBF.345668.nii')
img_arr=img.get_fdata()
img_arr=np.squeeze(img_arr)
img_arr=rotate(img_arr[:,:,2],90)
print('img_arr',img_arr.shape)
gw2=io.imshow(img_arr)
plt.show(gw2)
# Out:
# img_arr (256, 256)
# C:\Anaconda3\envs\py35\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:77: UserWarning: Float image out of standard range; displaying image with stretched contrast.
#   warn("Float image out of standard range; displaying "

# %%
header=img.header
print(header)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b''
# dim_info        : 0
# dim             : [  4 256 256   4  44   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : float32
# bitpix          : 32
# slice_start     : 0
# pixdim          : [-1.          0.97656202  0.97656202  5.          1.          1.          1.
#   1.        ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 0
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b''
# aux_file        : b''
# qform_code      : unknown
# sform_code      : aligned
# quatern_b       : 0.0
# quatern_c       : 0.0
# quatern_d       : 0.0
# qoffset_x       : 0.0
# qoffset_y       : 0.0
# qoffset_z       : 0.0
# srow_x          : [ 1.  0.  0.  0.]
# srow_y          : [ 0.  1.  0.  0.]
# srow_z          : [ 0.  0.  1.  0.]
# intent_name     : b''
# magic           : b'n+1'
